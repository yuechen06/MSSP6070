# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/drive/MyDrive/MSSP6070/data/InternetSales.csv'
df = pd.read_csv(file_path, encoding='latin1')



df.head()
df['OrderDate'] = pd.to_datetime(df['OrderDate'])
df['Year'] = df['OrderDate'].dt.year

yearly_sales = df.groupby('Year')['SalesAmount'].sum().reset_index()
yearly_sales


plt.figure(figsize=(8, 5))
plt.bar(yearly_sales['Year'], yearly_sales['SalesAmount'], color='skyblue')
plt.title('Yearly Internet Sales')
plt.xlabel('Year')
plt.ylabel('Total Sales ($)')
plt.grid(axis='y', linestyle='--', alpha=0.6)


plt.tight_layout()
output_path = '/content/drive/MyDrive/MSSP6070/data/Yearly_Internet_Sales.pdf'
plt.savefig(output_path)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /tmp/ipython-input-1247804796.py:7: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='latin1')
